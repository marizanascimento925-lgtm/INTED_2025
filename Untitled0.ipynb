# %% [markdown]
# <a href="https://colab.research.google.com/github/marizanascimento925-lgtm/INTED_2025/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
num = int(input('digite um número'))
if num >10:
   print(num, ' é maior que 10!')
elif num<10:
   print(num,'é menor que 10!')
else:
   print(num, 'é 10!!!')
# Out:
# digite um número11
# 11  é maior que 10!

# %%
#2
num = int(input('digite um número'))

if num % 2==0:
  print(num,'é par')
else:
  print(num,"é impar")
# Out:
# digite um número3
# 3 é impar

# %%
#3
nome=str(input('digite seu nome: '))
if 'a' in nome.lower():
  print('o nome tem a letra a')
else:
  print('o nome não tem a letra a')
# Out:
# digite seu nome: enzo
# o nome não tem a letra a

# %%
#4
x=int(input('digite um número'))
if x %5 == 0:
 print('é divisível por 5')
else:
 print('não é divísivel por 5')
# Out:
# digite um número5
# é divisível por 5

# %%
#5
temperatura = int(input('digite a temperatura atual:'))
if temperatura > 30:
  print('A temperatura esta quente.')
else:
  print("A temperatura esta fria.")
# Out:
# digite a temperatura atual:31
# A temperatura esta quente.

# %%
#6
letra = input('Digite S ou N')
if letra.lower() == 'n':
  print( letra, 'sair')
elif letra.lower() == 's':
  print('continuar')
else:
  print('ERROR')
# Out:
# Digite S ou NS
# continuar

# %%
#7
num = int(input('Digite o número'))
if num < 0:
  print(num,'negativo')
elif num == 0:
  print('igual a 0')
else:
  print(num, "positivo")
# Out:
# Digite o número87
# 87 positivo

# %%
#8
dia= int(input('Digite o valor do dia:'))
match dia:
  case 1: print("Domingo")
  case 2: print("Segunda-feira")
  case 3: print("Terça-feira")
  case 4: print('Quarta-feira')
  case 5: print("Quinta-feira")
  case 6: print('Sexta-feira')
  case 7: print("Sabádo")
  case _: print("não encontrado")
# Out:
# Digite o valor do dia:4
# Quarta-feira

# %%
#9
ano= int(input('Digite o ano:'))
if (ano%4 == 0 and ano%100 !=0) or (ano%400 == 0):
  print('O ano de' ,ano, 'não é bissexto')
else:
  print('O ano de',ano, 'não é bissexto')
# Out:
# Digite o ano:2008
# O ano de 2008 não é bissexto

# %%
#10
qtde_trab = int(input('Digite as horas trabalhadas:'))
valor_hora = float(input('Digite o valor:'))
if qtde_trab <=40:
  print('R$' ,qtde_trab * valor_hora)
else:
  print('R$',(qtde_trab * valor_hora)+(qtde_trab-40) * valor_hora * 1.5)
# Out:
# Digite as horas trabalhadas:150
# Digite o valor:60
# R$ 18900.0
