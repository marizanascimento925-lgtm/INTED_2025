# %% [markdown]
# <a href="https://colab.research.google.com/github/marizanascimento925-lgtm/INTED_2025/blob/main/28-10-2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
num = int(input('digite um número'))
if num >10:
   print(num, ' é maior que 10!')
elif num<10:
   print(num,'é menor que 10!')
else:
   print(num, 'é 10!!!')
# Out:
# digite um número11
# 11  é maior que 10!

# %%
#2
num = int(input('digite um número'))

if num % 2==0:
  print(num,'é par')
else:
  print(num,"é impar")
# Out:
# digite um número3
# 3 é impar

# %%
#3
nome=str(input('digite seu nome: '))
if 'a' in nome.lower():
  print('o nome tem a letra a')
else:
  print('o nome não tem a letra a')
# Out:
# digite seu nome: enzo
# o nome não tem a letra a

# %%
#4
x=int(input('digite um número'))
if x %5 == 0:
 print('é divisível por 5')
else:
 print('não é divísivel por 5')
# Out:
# digite um número5
# é divisível por 5

# %%
#5
temperatura = int(input('digite a temperatura atual:'))
if temperatura > 30:
  print('A temperatura esta quente.')
else:
  print("A temperatura esta fria.")
# Out:
# digite a temperatura atual:31
# A temperatura esta quente.

# %%
#6
texto = (input('digite S para continuar N para sair'))
