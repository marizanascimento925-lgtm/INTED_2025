# %% [markdown]
# <a href="https://colab.research.google.com/github/marizanascimento925-lgtm/INTED_2025/blob/main/Meu_primeiro_c%C3%B3digo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
b=5
c=10
print("a =",b+c)
# Out:
# a = 15

# %%
b=5
c=10
print("a =",b * c)
# Out:
# a = 50

# %%
b=20
c=10
d=35
print("a =",(b+c+d)/3)
# Out:
# a = 21.666666666666668

# %%
b=12
print("a =",b*2)
# Out:
# a = 24

# %%
b=100
c=2
print("a =",b%c)
# Out:
# a = 0

# %%
print(abs(-5+10))
# Out:
# 5

# %%
print(10//2)
# Out:
# 5

# %%
a = -2
b = 10
print('soma:',a+b,'modulo:',abs(a - b))
# Out:
# soma: 8 modulo: 12

# %%
n=2
print (n % 2 == 0)
# Out:
# True

# %%
a=5
b=2
print(5==2)
# Out:
# False

# %%
a=10
b=500
print(10+500>100)
# Out:
# True

# %%
idade=15
print(15>=18)
# Out:
# False

# %%
n=555
print(555 % 5==0)
# Out:
# True

# %%
a=2
b=4
print((2>0) and (4>0))
# Out:
# True

# %%
a=-2
b=-5
print((-2<0) and (-5<0))
# Out:
# True

# %%
 a=5
 b=10
 c=2
 d=4
 print((5 < 10) and (2 < 4))
# Out:
# True

# %%
a=15
b=25
c=35
print((15 + 25 > 35) and (15+ 35 > 25)and (25 + 35 > 15))
# Out:
# True

# %%
a=4
b=2
print((4 * 2 ) % 2 ==0)
# Out:
# True
